# %%
from radial_basis import GTORadialBasis, MonomialBasis, ShiftedGTORadialBasis

# %%
n = 4
l = 4
shift = 1.0
width = 0.5
cutoff = 5

shared_params = dict(max_radial=n, max_angular=l, cutoff_radius=cutoff)

# %%
monomial = MonomialBasis(**shared_params)
monomial.plot_basis()

# %%
shiftedgto = ShiftedGTORadialBasis(
    radial_gaussian_width=width,
    # radial_gaussian_shift = shift,
    tol=1e-1,
    **shared_params
)
shiftedgto.plot_basis()

# %%
gto = GTORadialBasis(radial_gaussian_width=width, **shared_params)
gto.plot_basis()

# %%
gto = GTORadialBasis(**shared_params)
gto.plot_basis()

# %%
np.arange(np.array([0, 1, 6]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 np.arange(np.array([0,1,6]))
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
import numpy as np
